# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform

numbers = uniform.rvs(2, 8, size=10)

# %%
numbers
# Out:
# array([8.77457746, 4.42594999, 7.26601027, 5.64563151, 9.3873787 ,
#        4.92616002, 5.67320738, 5.89781507, 2.11814221, 3.90058962])

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
from scipy.stats import uniform
import matplotlib.pyplot as plt

# %%
def generate_uniform(bottom, ceiling, count):
    """
    Generate uniformly distributed random numbers.
    
    Parameters:
        bottom (float): lower boundary
        ceiling (float): upper boundary
        count (int): number of values to generate
        
    Returns:
        array: uniformly distributed random numbers
    """
    scale = ceiling - bottom
    return uniform.rvs(loc=bottom, scale=scale, size=count)

# %%
numbers_100 = generate_uniform(bottom=10, ceiling=15, count=100)
numbers_1000 = generate_uniform(bottom=10, ceiling=60, count=1000)

# %%
plt.figure(figsize=(12, 5))

# First distribution
plt.subplot(1, 2, 1)
plt.hist(numbers_100, bins=10)
plt.title("Uniform Distribution")
plt.xlabel("Value")
plt.ylabel("Count")

# Second distribution
plt.subplot(1, 2, 2)
plt.hist(numbers_1000, bins=10)
plt.title("Uniform Distribution")
plt.xlabel("Value")
plt.ylabel("Count")

plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %%
def generate_normal(mean, std, count):
    """
    Generate normally distributed random numbers.
    
    Parameters:
        mean (float): mean (average) of the distribution
        std (float): standard deviation
        count (int): number of values to generate
        
    Returns:
        array: normally distributed random numbers
    """
    return norm.rvs(loc=mean, scale=std, size=count)

# %%
normal_std_1 = generate_normal(mean=10, std=1, count=1000)
normal_std_50 = generate_normal(mean=10, std=50, count=1000)

# %%
plt.figure(figsize=(12, 5))

# Normal distribution with std = 1
plt.subplot(1, 2, 1)
plt.hist(normal_std_1, bins=30)
plt.title("Normal Distribution")
plt.xlabel("Value")
plt.ylabel("Count")

# Normal distribution with std = 50
plt.subplot(1, 2, 2)
plt.hist(normal_std_50, bins=30)
plt.title("Normal Distribution")
plt.xlabel("Value")
plt.ylabel("Count")

plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [raw]
# Your answer here

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
df = pd.read_csv("vehicles.csv")

# %%
df.head(5)
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
fuel_barrels = df["Fuel Barrels/Year"].dropna()

# %%
plt.figure(figsize=(8, 5))
plt.hist(fuel_barrels, bins=30)
plt.xlabel("Fuel Barrels per Year")
plt.ylabel("Count")
plt.title("Distribution of Fuel Barrels per Year")
plt.show()

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
co2 = df["CO2 Emission Grams/Mile"].dropna()

# %%
plt.figure(figsize=(8, 5))
plt.hist(co2, bins=30)
plt.xlabel("CO2 Emissions (grams/mile)")
plt.ylabel("Count")
plt.title("Distribution of CO2 Emissions per Mile")
plt.show()

# %% [markdown]
# 3. Combined MPG

# %%
cmpg = df["Combined MPG"].dropna()

# %%
plt.figure(figsize=(8, 5))
plt.hist(cmpg, bins=30)
plt.xlabel("Combined MPG")
plt.ylabel("Count")
plt.title("MPG")
plt.show()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
fuel_barrels.describe()
# Out:
# count    35952.000000
# mean        17.609056
# std          4.467283
# min          0.060000
# 25%         14.699423
# 50%         17.347895
# 75%         20.600625
# max         47.087143
# Name: Fuel Barrels/Year, dtype: float64

# %%
co2.describe()
# Out:
# count    35952.000000
# mean       475.316339
# std        119.060773
# min         37.000000
# 25%        395.000000
# 50%        467.736842
# 75%        555.437500
# max       1269.571429
# Name: CO2 Emission Grams/Mile, dtype: float64

# %%
cmpg.describe()
# Out:
# count    35952.000000
# mean        19.929322
# std          5.112409
# min          7.000000
# 25%         16.000000
# 50%         19.000000
# 75%         23.000000
# max         56.000000
# Name: Combined MPG, dtype: float64

# %%
# your code here

# %% [markdown]
# None of them are normally ditributed.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

def generate_exponential(mean, size):
    # numpy's scale parameter is the mean (1/lambda)
    return np.random.exponential(scale=mean, size=size)

# %%
mean_val = 10

# Generate sequence of size 10
seq_10 = generate_exponential(mean_val, 10)

# Generate sequence of size 100
seq_100 = generate_exponential(mean_val, 100)

# %%
# Setting up the figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Plot for size 10
ax1.hist(seq_10, bins=100, color='skyblue', edgecolor='black')
ax1.set_title("Exponential Distribution (Size=10)")
ax1.set_xlabel("Value")
ax1.set_ylabel("Frequency")

# Plot for size 100
ax2.hist(seq_100, bins=100, color='salmon', edgecolor='black')
ax2.set_title("Exponential Distribution (Size=100)")
ax2.set_xlabel("Value")
ax2.set_ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# The mean changes, so the distribution changes as well.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
from scipy.stats import expon

# Parameters
mean_time = 10
threshold_time = 15

# In scipy.stats.expon, 'scale' is the mean (1/lambda)
prob_less_than_15 = expon.cdf(threshold_time, scale=mean_time)
prob_less_than_15 = prob_less_than_15*100

print(f"The probability that a customer spends less than 15 minutes is: {prob_less_than_15:.2f}%")
# Out:
# The probability that a customer spends less than 15 minutes is: 77.69%

# %%
# your answer here
# Hint: This is same as saying P(x<15)

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
prob_more_than_15 = 100 - prob_less_than_15

print(f"The probability that a customer spends more than 15 minutes is: {prob_more_than_15:.2f}%")
# Out:
# The probability that a customer spends more than 15 minutes is: 22.31%
